# %% [markdown]
# ## Use Scanpy to read the AnnData file
#
# AnnData documentation: https://anndata.readthedocs.io/en/latest/index.html
#
# ![AnnData Schema](https://raw.githubusercontent.com/scverse/anndata/main/docs/_static/img/anndata_schema.svg)

# %%
import pandas as pd
import scanpy

# %%
bladder = scanpy.read_h5ad(
    "/Users/olga/Downloads/4229bba1-974c-4595-ac5c-15a9035c5688.h5ad"
)

# %%
bladder
# Out:
# AnnData object with n_obs × n_vars = 2432 × 21069
#     obs: 'FACS.selection', 'age', 'cell', 'free_annotation', 'method', 'donor_id', 'n_genes', 'n_counts', 'louvain', 'leiden', 'assay_ontology_term_id', 'disease_ontology_term_id', 'cell_type_ontology_term_id', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'suspension_type', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'n_cells', 'means', 'dispersions', 'dispersions_norm', 'highly_variable', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'age_colors', 'citation', 'leiden', 'louvain', 'neighbors', 'pca', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### Expression data is a numpy compressed CSR matrix

# %%
bladder.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 10186830 stored elements and shape (2432, 21069)>

# %% [markdown]
# ## Export the expression data (the "X" samples x feature matrix) to a pandas dataframe
#
# For some large datasets, this won't work on your machine and you'll need to write to parquet directly from the Numpy `.X` object.

# %%
expression = bladder.to_df()
print(expression.shape)
expression.head()
# Out:
# (2432, 21069)
#                                         ENSMUSG00000029422  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0            1.546881
# A12_B002723_B009459_S264.mm10-plus-1-0            1.760437
# A12_D045324_B009460_S48.mm10-plus-1-0             2.546988
# A13_B002346_B009249_S181.mm10-plus-1-0            2.084349
# A13_B002723_B009459_S265.mm10-plus-1-0            2.090320
#
#                                         ENSMUSG00000076126  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000049036  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000029577  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0            0.818400
# A12_B002723_B009459_S264.mm10-plus-1-0            0.000000
# A12_D045324_B009460_S48.mm10-plus-1-0             0.000000
# A13_B002346_B009249_S181.mm10-plus-1-0            0.772625
# A13_B002723_B009459_S265.mm10-plus-1-0            0.000000
#
#                                         ENSMUSG00000040746  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0            2.584122
# A12_B002723_B009459_S264.mm10-plus-1-0            0.045921
# A12_D045324_B009460_S48.mm10-plus-1-0             2.454049
# A13_B002346_B009249_S181.mm10-plus-1-0            1.284956
# A13_B002723_B009459_S265.mm10-plus-1-0            0.201467
#
#                                         ENSMUSG00000020590  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0            0.000000
# A12_B002723_B009459_S264.mm10-plus-1-0            0.000000
# A12_D045324_B009460_S48.mm10-plus-1-0             0.000000
# A13_B002346_B009249_S181.mm10-plus-1-0            4.948908
# A13_B002723_B009459_S265.mm10-plus-1-0            0.000000
#
#                                         ENSMUSG00000030263  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000038914  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0            0.000000
# A12_B002723_B009459_S264.mm10-plus-1-0            2.885492
# A12_D045324_B009460_S48.mm10-plus-1-0             0.000000
# A13_B002346_B009249_S181.mm10-plus-1-0            1.615562
# A13_B002723_B009459_S265.mm10-plus-1-0            0.000000
#
#                                         ENSMUSG00000026878  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0            3.101860
# A12_B002723_B009459_S264.mm10-plus-1-0            1.350023
# A12_D045324_B009460_S48.mm10-plus-1-0             2.289170
# A13_B002346_B009249_S181.mm10-plus-1-0            2.909233
# A13_B002723_B009459_S265.mm10-plus-1-0            2.844065
#
#                                         ENSMUSG00000093241  ...  \
# index                                                       ...
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0  ...
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0  ...
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0  ...
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0  ...
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0  ...
#
#                                         ENSMUSG00000095543  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000065511  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000035875  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000020070  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000030178  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000102368  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000021033  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0            1.372477
# A12_B002723_B009459_S264.mm10-plus-1-0            0.000000
# A12_D045324_B009460_S48.mm10-plus-1-0             0.000000
# A13_B002346_B009249_S181.mm10-plus-1-0            0.000000
# A13_B002723_B009459_S265.mm10-plus-1-0            2.879196
#
#                                         ENSMUSG00000073940  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0
#
#                                         ENSMUSG00000037924  ENSMUSG00000040693
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                 0.0                 0.0
# A12_B002723_B009459_S264.mm10-plus-1-0                 0.0                 0.0
# A12_D045324_B009460_S48.mm10-plus-1-0                  0.0                 0.0
# A13_B002346_B009249_S181.mm10-plus-1-0                 0.0                 0.0
# A13_B002723_B009459_S265.mm10-plus-1-0                 0.0                 0.0
#
# [5 rows x 21069 columns]

# %%
expression.to_parquet("../data/bladder_smartseq2_expression.parquet")

# %% [markdown]
# ## Metadata

# %% [markdown]
# ### Per-cell metadata
#
# This may be more familiar to you as a `y` target vector value, as any of these columns could be a target vector for classification/regression.

# %%
print(bladder.obs.shape)
bladder.obs.head()
# Out:
# (2432, 30)
#                                        FACS.selection  age         cell  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0       Multiple  18m  A11_B002346
# A12_B002723_B009459_S264.mm10-plus-1-0       Multiple  18m  A12_B002723
# A12_D045324_B009460_S48.mm10-plus-1-0        Multiple  18m  A12_D045324
# A13_B002346_B009249_S181.mm10-plus-1-0       Multiple  18m  A13_B002346
# A13_B002723_B009459_S265.mm10-plus-1-0       Multiple  18m  A13_B002723
#
#                                        free_annotation method donor_id  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0             nan   facs  18_47_F
# A12_B002723_B009459_S264.mm10-plus-1-0             nan   facs  18_53_M
# A12_D045324_B009460_S48.mm10-plus-1-0              nan   facs  18_45_M
# A13_B002346_B009249_S181.mm10-plus-1-0             nan   facs  18_47_F
# A13_B002723_B009459_S265.mm10-plus-1-0             nan   facs  18_53_M
#
#                                         n_genes  n_counts louvain leiden  ...  \
# index                                                                     ...
# A11_B002346_B009249_S179.mm10-plus-1-0     4582  159863.0       3      5  ...
# A12_B002723_B009459_S264.mm10-plus-1-0     3537  875472.0       3      4  ...
# A12_D045324_B009460_S48.mm10-plus-1-0      4179  930126.0       1      0  ...
# A13_B002346_B009249_S181.mm10-plus-1-0     4139  113449.0       0     10  ...
# A13_B002723_B009459_S265.mm10-plus-1-0     3451   95993.0       3      7  ...
#
#                                        tissue_type                cell_type  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0      tissue  bladder urothelial cell
# A12_B002723_B009459_S264.mm10-plus-1-0      tissue  bladder urothelial cell
# A12_D045324_B009460_S48.mm10-plus-1-0       tissue  bladder urothelial cell
# A13_B002346_B009249_S181.mm10-plus-1-0      tissue  bladder urothelial cell
# A13_B002723_B009459_S265.mm10-plus-1-0      tissue  bladder urothelial cell
#
#                                              assay disease      organism  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0  Smart-seq2  normal  Mus musculus
# A12_B002723_B009459_S264.mm10-plus-1-0  Smart-seq2  normal  Mus musculus
# A12_D045324_B009460_S48.mm10-plus-1-0   Smart-seq2  normal  Mus musculus
# A13_B002346_B009249_S181.mm10-plus-1-0  Smart-seq2  normal  Mus musculus
# A13_B002723_B009459_S265.mm10-plus-1-0  Smart-seq2  normal  Mus musculus
#
#                                            sex         tissue  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0  female  bladder lumen
# A12_B002723_B009459_S264.mm10-plus-1-0    male  bladder lumen
# A12_D045324_B009460_S48.mm10-plus-1-0     male  bladder lumen
# A13_B002346_B009249_S181.mm10-plus-1-0  female  bladder lumen
# A13_B002723_B009459_S265.mm10-plus-1-0    male  bladder lumen
#
#                                         self_reported_ethnicity  \
# index
# A11_B002346_B009249_S179.mm10-plus-1-0                       na
# A12_B002723_B009459_S264.mm10-plus-1-0                       na
# A12_D045324_B009460_S48.mm10-plus-1-0                        na
# A13_B002346_B009249_S181.mm10-plus-1-0                       na
# A13_B002723_B009459_S265.mm10-plus-1-0                       na
#
#                                          development_stage observation_joinid
# index
# A11_B002346_B009249_S179.mm10-plus-1-0  18-month-old stage         =3O1^YgPZ7
# A12_B002723_B009459_S264.mm10-plus-1-0  18-month-old stage         Y&&COYqNyI
# A12_D045324_B009460_S48.mm10-plus-1-0   18-month-old stage         2`MY>a57{z
# A13_B002346_B009249_S181.mm10-plus-1-0  18-month-old stage         <1w2Fh}t@p
# A13_B002723_B009459_S265.mm10-plus-1-0  18-month-old stage         VhDDdwlrQ`
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Write per-cell (samples) metadata to parquet
#
# `.obs` is the metadata on the samples in AnnData parlance.

# %%
bladder.obs.to_parquet("../data/bladder_smartseq2_sample_metadata.parquet")

# %% [markdown]
# ### Per-gene metadata
#
# `.var` is the metadata on the features in AnnData parlance

# %%
print(bladder.var.shape)
bladder.var.head()
# Out:
# (21069, 11)
#                     n_cells         means  dispersions  dispersions_norm  \
# ENSMUSG00000029422    65053  7.885286e-01     0.236148         -0.827445
# ENSMUSG00000076126       20  1.000000e-12          NaN               NaN
# ENSMUSG00000049036     3000  4.733051e-03     0.282755          0.497139
# ENSMUSG00000029577    22639  1.112182e-01     0.216849          0.453594
# ENSMUSG00000040746    52908  5.102730e-01     0.668143          0.372446
#
#                     highly_variable  feature_is_filtered  \
# ENSMUSG00000029422            False                False
# ENSMUSG00000076126            False                False
# ENSMUSG00000049036            False                False
# ENSMUSG00000029577            False                False
# ENSMUSG00000040746            False                False
#
#                                   feature_name feature_reference  \
# ENSMUSG00000029422    Rsrc2_ENSMUSG00000029422   NCBITaxon:10090
# ENSMUSG00000076126                     Mir669b   NCBITaxon:10090
# ENSMUSG00000049036  Tmem121_ENSMUSG00000049036   NCBITaxon:10090
# ENSMUSG00000029577    Ube3b_ENSMUSG00000029577   NCBITaxon:10090
# ENSMUSG00000040746   Rnf167_ENSMUSG00000040746   NCBITaxon:10090
#
#                    feature_biotype feature_length    feature_type
# ENSMUSG00000029422            gene           1377  protein_coding
# ENSMUSG00000076126            gene             97           miRNA
# ENSMUSG00000049036            gene           1574  protein_coding
# ENSMUSG00000029577            gene           3879  protein_coding
# ENSMUSG00000040746            gene            867  protein_coding

# %% [markdown]
# #### Write per-gene (features) metadata to parquet

# %%
bladder.var.to_parquet("../data/bladder_smartseq2_feature_metadata.parquet")

# %% [markdown]
# ## Show unstructured data

# %%
bladder.uns
# Out:
# {'age_colors': array(['#e1f3b2', '#97d6b9', '#1f80b8'], dtype=object),
#  'citation': 'Publication: https://doi.org/10.1038/s41586-020-2496-1 Dataset Version: https://datasets.cellxgene.cziscience.com/4229bba1-974c-4595-ac5c-15a9035c5688.h5ad curated and distributed by CZ CELLxGENE Discover in Collection: https://cellxgene.cziscience.com/collections/0b9d8a04-bb9d-44da-aa27-705bb65b54eb',
#  'leiden': {'params': {'n_iterations': array([-1]),
#    'random_state': array([0]),
#    'resolution': array([1])}},
#  'louvain': {'params': {'random_state': array([0])}},
#  'neighbors': {'params': {'method': array(['umap'], dtype=object),
#    'metric': array(['euclidean'], dtype=object),
#    'n_neighbors': array([15]),
#    'n_pcs': array([5])}},
#  'pca': {'variance': array([454.20193  ,  78.98866  ,  64.31594  ,  34.90398  ,  29.65793  ,
#           23.4138   ,  18.985216 ,  16.46509  ,  15.075678 ,  13.814811 ,
#           12.145706 ,  11.504896 ,  10.541939 ,   9.79446  ,   9.070989 ,
#            8.92252  ,   8.503054 ,   8.103258 ,   8.041878 ,   7.7786684,
#            7.5457053,   7.2816057,   6.9277577,   6.757199 ,   6.6483755,
#            6.572561 ,   6.369706 ,   6.2938485,   6.1824265,   6.1274037,
#            6.0211906,   5.9240847,   5.908889 ,   5.8009152,   5.755654 ,
#            5.7022033,   5.690658 ,   5.641061 ,   5.6269794,   5.5870123,
#            5.5291743,   5.5026264,   5.4553494,   5.4429607,   5.4211445,
#            5.39407  ,   5.346145 ,   5.33309  ,   5.320369 ,   5.290338 ],
#         dtype=float32),
#   'variance_ratio': array([0.098781  , 0.01717866, 0.0139876 , 0.00759101, 0.00645008,
#          0.00509209, 0.00412895, 0.00358087, 0.0032787 , 0.00300448,
#          0.00264148, 0.00250211, 0.00229269, 0.00213012, 0.00197278,
#          0.00194049, 0.00184927, 0.00176232, 0.00174897, 0.00169172,
#          0.00164106, 0.00158362, 0.00150667, 0.00146957, 0.00144591,
#          0.00142942, 0.0013853 , 0.0013688 , 0.00134457, 0.0013326 ,
#          0.0013095 , 0.00128839, 0.00128508, 0.0012616 , 0.00125175,
#          0.00124013, 0.00123762, 0.00122683, 0.00122377, 0.00121508,
#          0.0012025 , 0.00119673, 0.00118644, 0.00118375, 0.001179  ,
#          0.00117312, 0.00116269, 0.00115985, 0.00115709, 0.00115056],
#         dtype=float32)},
#  'schema_reference': 'https://github.com/chanzuckerberg/single-cell-curation/blob/main/schema/5.3.0/schema.md',
#  'schema_version': '5.3.0',
#  'title': 'Bladder lumen - A single-cell transcriptomic atlas characterizes ageing tissues in the mouse - Smart-seq2'}

# %%
type(bladder.uns)
# Out:
# dict

# %% [markdown]
# #### Make object JSON serializable

# %%
import json

import numpy as np


def make_json_serializable(obj):
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, dict):
        return {k: make_json_serializable(v) for k, v in obj.items()}
    elif isinstance(obj, (list, tuple)):
        return [make_json_serializable(i) for i in obj]
    elif isinstance(obj, (np.integer, np.floating)):
        return obj.item()
    else:
        return obj


# Convert to JSON-serializable object
bladder_uns_serializable = make_json_serializable(bladder.uns)

# Save to file
with open("../data/bladder_smartseq2_unstructured_metadata.json", "w") as f:
    json.dump(bladder_uns_serializable, f, indent=2)

# %% [markdown]
# ## Save the `X_*` matrices from `obsm`
#
# These matrices are a transformation of the expression data, transforming from (samples x features) to (samples x latent space)

# %%
bladder.obsm_keys()
# Out:
# ['X_pca', 'X_tsne', 'X_umap']

# %%
bladder.obsm
# Out:
# AxisArrays with keys: X_pca, X_tsne, X_umap

# %%
for key in bladder.obsm_keys():
    X = bladder.obsm[key]
    df = pd.DataFrame(X, index=bladder.obs_names)
    print(f"key: {key}, shape: {df.shape}")
    df.to_parquet(f"../data/bladder_smartseq2_projection_{key}.parquet")
# Out:
# key: X_pca, shape: (2432, 50)
# key: X_tsne, shape: (2432, 2)
# key: X_umap, shape: (2432, 2)
